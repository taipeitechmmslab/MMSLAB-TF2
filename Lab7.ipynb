# %% [markdown]
# # TensorBoard進階技巧

# %% [markdown]
# ## tf.summary
#
# tf.summary是TensorFlow提供TensorBoard低階API指令，主要是用來紀錄log檔。
# 以下整理了幾個常用功能：
# - tf.scalar：儲存顯示如損失、指標或學習率等的變化趨勢。
# - tf.image：儲存顯示影像。
# - tf.audio：儲存顯示可播放的音頻。
# - tf.histogram：儲存顯示模型權重。
# - tf.text：儲存顯示一段文字。

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 創建TensorBoard log檔

# %%
summary_writer = tf.summary.create_file_writer('lab7-logs-summary')

# %% [markdown]
# ### Scalar

# %%
# 在0~2π之間產生100個點
x = np.linspace(0, 2 * np.pi , 100)
# 將100個點帶入sin函數中
data = np.sin(x)
with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔
    for i, y in enumerate(data):
        tf.summary.scalar('sin', y, step=i)  # 存入數值(y為數值，i為時間軸)

# %% [markdown]
# ### Image

# %% [markdown]
# 1. 儲存一張影像在紀錄檔中並顯示

# %%
# 建立讀取影像的函數
def read_img(file):
    image_string = tf.io.read_file(file)  # 讀取檔案
    # 將讀入檔案以影像格式來解碼
    image_decode = tf.image.decode_image(image_string)
    # 將影像增加一個維度(number,height,width,channel)方便之後存入紀錄檔中
    # image_decode = tf.expand_dims(image_decode, axis=0)
    return image_decode

img = read_img('image/airplane.png')  # 讀入影像資訊
plt.imshow(img)  # 顯示讀入的影像資訊

# %%
image_string = tf.io.read_file('image/airplane.png')  # 讀取檔案
image_decode = tf.image.decode_image(image_string)

# %%
with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔
    tf.summary.image("Airplane", [image_decode], step=0)  # 存入影像資訊

# %% [markdown]
# 2. 一次儲存五張影像到紀錄檔中並顯示

# %%
# !ls image/
# Out:
# airplane.png	    airplane_flip.png  airplane_zoom.png
# airplane_color.png  airplane_rot.png   elephant.jpg

# %%
img_files = ['airplane_zoom.png', 'airplane_flip.png', 'airplane_color.png', 'airplane_rot.png',
             'airplane.png']  # 創建一個陣列用來儲存讀入的影像 

imgs = [] 

for file in img_files: 
    imgs.append(read_img('image/'+file))  # 讀取影像並存入陣列中 

with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔 
    # 一次存入五張影像(注意:如果max_outputs沒設定為5，就只會儲存3張影像) 
    tf.summary.image("Airplane Augmentation", imgs, max_outputs=5, step=0)

# %% [markdown]
# 3. 將五張影像以不同Step(時間)儲存

# %%
with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔
    # 每次儲存一張影像，並儲存在不同Step中
    for i, img in enumerate(imgs):
        tf.summary.image("Save image each step", [img], step=i)

# %% [markdown]
# ### Text

# %%
# 建立一個陣列，裡面包含了對話記錄
texts = ["小明：Cubee小助理最近好想學深度學習的技術哦!", 
         "Cubee：這是當然的阿，這可現今最火的技術呢!", 
         "小明：那我該如何入門呢?", 
         "Cubee：推薦你一本書「輕鬆學會Google TensorFlow2.0深度學習」。", 
         "小明：這本書沒有深度學習經驗的人也能學會嗎?", 
         "Cubee：這是當然的，你只需要基礎Python能力就可以學會了!", 
         "小明：太好了那我要趕快去買了!"]

with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔
    # 將每一段字串資訊以不同Step存入到記錄檔中
    for i, text in enumerate(texts):
        tf.summary.text("Chat record", text, step=i)

# %% [markdown]
# ### Audio

# %%
# 建立讀取音訊的函數
def read_audio(file):
    audio_string = tf.io.read_file(file)  # 讀取檔案
    # 將讀入檔案以音訊格式來解碼
    audio, fs = tf.audio.decode_wav(audio_string)
    # 因為tf.summary.audio要求輸入格式為[k(clips), t(frames), c(channels)]
    # 而解碼後的音訊只有[t(frames), c(channels)]，所以需要增加一個維度給音訊
    audio = tf.expand_dims(audio, axis=0)
    return audio, fs

audio, fs = read_audio('./audio/cat.wav')  # 讀取音訊檔

with summary_writer.as_default():  # summary_writer作為預設寫入的紀錄檔
    tf.summary.audio('cat', audio, fs, step=0)  # 存入音訊資訊

# %% [markdown]
# ### Histogram
#
# 目前 TensorFlow-gpu 2.0-alpha有問題，等待下一版修復。
#
# https://github.com/tensorflow/tensorboard/issues/1993

# %% [markdown]
# 建立一個常態分佈

# %%
data = tf.random.normal([64, 100], dtype=tf.float64)

# %% [markdown]
# 儲存常態分佈分佈

# %%
with summary_writer.as_default():
    tf.summary.histogram('Normal distribution', data, step=0)

# %% [markdown]
# 儲存多個常態分佈，並且各個之間平均值都相差0.01

# %%
with summary_writer.as_default():
    for i, offset in enumerate(tf.range(0, 10, delta=0.1, dtype=tf.float64)):
        tf.summary.histogram('Normal distribution 2', data+offset, step=i)

# %% [markdown]
# # 實驗一：使用tf.summary.image紀錄訓練結果

# %% [markdown]
# ### Import 必要套件

# %%
import os
import io
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from preprocessing import parse_aug_fn, parse_fn

# %% [markdown]
# ### Confusion matrix

# %% [markdown]
# Confusion matrix函數：透過tf.math.confusion_matrix來計算Confusion matrix。

# %%
y_true = [2, 1, 0, 2, 2, 0, 1, 1]
y_pred = [0, 1, 0, 2, 2, 0, 2, 1]
cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=3).numpy()
print(cm)
# Out:
# [[2 0 0]
#  [0 2 1]
#  [1 0 2]]

# %% [markdown]
# 建立plot_confusion_matrix函式：將剛剛上方計算的Confusion matrix陣列以Matplotlib圖片來表示，而Confusion matrix中的數字改成百分比型式。

# %%
def plot_confusion_matrix(cm, class_names):
    """
    產生一張圖表示的Confusion matrix
    
    Args:
    cm (shape = [n, n]): 傳入Confusion matrix
    class_names (shape = [n]): 傳入類別
    """
    # 標準化confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
    
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    tick_index = np.arange(len(class_names))
    # Y軸顯示類別名稱
    plt.yticks(tick_index, class_names)
    # X軸顯示類別名稱，並將類別名稱旋轉45度(避免文字重疊)
    plt.xticks(tick_index, class_names, rotation=45)
    # 再圖片右邊產生一條顏色刻度條
    plt.colorbar()

    # 在每一格Confusion matrix輸入預測百分比
    threshold = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            # 如果格內背景顏色太深使用白色文字顯示，反之使用黑色文字
            color = "white" if cm[i, j] > threshold else "black"
            plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)
            
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    # 將圖片的位置進行調整，避免x或y軸的文字被遮擋
    plt.tight_layout()
    return figure

# Example
img = plot_confusion_matrix(cm, [0, 1, 2])

# %% [markdown]
# 建立plot_to_image函數：將Matplotlib圖片轉TensorFlow型式的圖片，這樣才能夠透過tf.summary.image紀錄影像到TensorBoard。

# %%
def plot_to_image(figure):
    """將Matplotlib plot的圖片轉TensorFlow的張量格式"""
    # 將Matplotlib plot的圖片以PNG的格式儲存到記憶體中
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # 關閉plt圖片，防止圖片直接顯示在Jupyter notebook介面中
    plt.close(figure)
    buf.seek(0)
    # 將記憶體中的資料轉成TensorFlow格式
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    image = tf.expand_dims(image, 0)
    return image

# %%
# Example
y_true = [2, 0, 2, 2, 0, 1]
y_pred = [0, 0, 2, 2, 0, 2]
cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=3).numpy()
img = plot_confusion_matrix(cm, [0, 1, 2])
img_show = plot_to_image(img)

# %% [markdown]
# ### 創建Callback函數
# 創建回調函數：訓練過程中每個epoch結束，會產生一張Confusion matrix的圖片，並將圖片紀錄在Tensorboard上。

# %%
class ConfusionMatrix(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, test_data, class_name):
        super(ConfusionMatrix, self).__init__()
        self.log_dir = log_dir
        self.test_data = test_data
        self.class_names = class_name
        self.num_classes = len(class_name)

    def on_train_begin(self, logs=None):
        path = os.path.join(self.log_dir, 'confusion_matrix')
        # 創建TensorBoard紀錄檔
        self.writer = tf.summary.create_file_writer(path)

    def on_epoch_end(self, epoch, logs=None):
        # 計算Confusion matrix
        total_cm = np.zeros([10, 10])
        for x, y_true in self.test_data:
            y_pred = self.model.predict(x)
            y_pred = np.argmax(y_pred, axis=1)
            y_true = np.argmax(y_true, axis=1)
            cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes).numpy()
            total_cm += cm
        
        # 將Confusion matrix轉成Matplotlib圖片
        figure = plot_confusion_matrix(total_cm, class_names=self.class_names)
        # 將Matplotlib圖片轉成TensorFlow型式的圖片
        cm_image = plot_to_image(figure)

        # 將圖片紀錄在TensorBoard log中
        with self.writer.as_default():
            tf.summary.image("Confusion Matrix", cm_image, step=epoch)

# %% [markdown]
# ### 訓練網路模型

# %% [markdown]
# 載入CIFAR-10數據集：

# %%
# 將train Data重新分成1:9等分，分別分給valid data, train data
valid_split, train_split = tfds.Split.TRAIN.subsplit([10, 90])
# 取得訓練數據，並順便讀取data的資訊
train_data, info = tfds.load("cifar10", split=train_split, with_info=True)
# 取得驗證數據
valid_data = tfds.load("cifar10", split=valid_split)
# 取得測試數據
test_data = tfds.load("cifar10", split=tfds.Split.TEST)
# 取得CIFAR-10數據集的類別
class_name = info.features['label'].names

# %% [markdown]
# Dataset 設定；

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE  # 自動調整模式
batch_size = 64  # 批次大小
train_num = int(info.splits['train'].num_examples / 10) * 9  # 訓練資料數量

train_data = train_data.shuffle(train_num)  # 打散資料集
# 載入預處理「 parse_aug_fn」function，cpu數量為自動調整模式
train_data = train_data.map(map_func=parse_aug_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
train_data = train_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# 載入預處理「 parse_fn」function，cpu數量為自動調整模式
valid_data = valid_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
valid_data = valid_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# 載入預處理「 parse_fn」function，cpu數量為自動調整模式
test_data = test_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
test_data = test_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# 建立網路模型：

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(64, 3, activation='relu', kernel_initializer='glorot_uniform')(inputs)
x = layers.MaxPool2D()(x)
x = layers.Conv2D(128, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(256, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(128, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(64, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10)(x)
# 建立網路模型(將輸入到輸出所有經過的網路層連接起來)
model_1 = keras.Model(inputs, outputs, name='model 1')
model_1.summary()
# Out:
# Model: "model 1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 128)         295040
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                200768
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 941,066
# Trainable params: 941,066
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 建立Callback function：

# %%
# 儲存訓練記錄檔
logs_dirs = 'lab7-logs-images'
model_cbk = keras.callbacks.TensorBoard(logs_dirs)
# 儲存Confusion matrix圖片
save_cm = ConfusionMatrix(logs_dirs, test_data, class_name)

# %% [markdown]
# 設定訓練使用的優化器、客自化損失函數和客自化指標函數：

# %%
model_1.compile(keras.optimizers.Adam(), 
                loss=keras.losses.CategoricalCrossentropy(from_logits=True), 
                metrics=[keras.metrics.CategoricalAccuracy()])

# %% [markdown]
# 訓練網路模型：

# %%
model_1.fit(train_data,
            epochs=100, 
            validation_data=valid_data,
            callbacks=[model_cbk, save_cm])
# Out:
# Epoch 1/100
#       1/Unknown - 4s 4s/step - loss: 2.3080 - categorical_accuracy: 0.1094
# WARNING: Logging before flag parsing goes to stderr.
# W0629 20:55:55.693831 139815137187648 callbacks.py:241] Method (on_train_batch_end) is slow compared to the batch update (0.128922). Check your callbacks.
# 704/704 [==============================] - 16s 22ms/step - loss: 2.0773 - categorical_accuracy: 0.2196 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.8722 - categorical_accuracy: 0.3069 - val_loss: 1.5641 - val_categorical_accuracy: 0.4276
# Epoch 3/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.7459 - categorical_accuracy: 0.3602 - val_loss: 1.4246 - val_categorical_accuracy: 0.4756
# Epoch 4/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.6568 - categorical_accuracy: 0.3955 - val_loss: 1.3370 - val_categorical_accuracy: 0.5268
# Epoch 5/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.5911 - categorical_accuracy: 0.4272 - val_loss: 1.2556 - val_categorical_accuracy: 0.5528
# Epoch 6/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.5312 - categorical_accuracy: 0.4474 - val_loss: 1.1968 - val_categorical_accuracy: 0.5718
# Epoch 7/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.4757 - categorical_accuracy: 0.4735 - val_loss: 1.1474 - val_categorical_accuracy: 0.5916
# Epoch 8/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.4323 - categorical_accuracy: 0.4931 - val_loss: 1.0755 - val_categorical_accuracy: 0.6198
# Epoch 9/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.4027 - categorical_accuracy: 0.5083 - val_loss: 1.0345 - val_categorical_accuracy: 0.6330
# Epoch 10/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.3665 - categorical_accuracy: 0.5201 - val_loss: 1.0419 - val_categorical_accuracy: 0.6278
# Epoch 11/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.3257 - categorical_accuracy: 0.5379 - val_loss: 1.0120 - val_categorical_accuracy: 0.6378
# Epoch 12/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.3041 - categorical_accuracy: 0.5440 - val_loss: 0.9637 - val_categorical_accuracy: 0.6552
# Epoch 13/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.2738 - categorical_accuracy: 0.5560 - val_loss: 0.9440 - val_categorical_accuracy: 0.6630
# Epoch 14/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.2508 - categorical_accuracy: 0.5664 - val_loss: 0.9294 - val_categorical_accuracy: 0.6730
# Epoch 15/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.2361 - categorical_accuracy: 0.5700 - val_loss: 0.9401 - val_categorical_accuracy: 0.6660
# Epoch 16/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.2085 - categorical_accuracy: 0.5823 - val_loss: 0.9062 - val_categorical_accuracy: 0.6832
# Epoch 17/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1907 - categorical_accuracy: 0.5896 - val_loss: 0.8691 - val_categorical_accuracy: 0.6872
# Epoch 18/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.1738 - categorical_accuracy: 0.5967 - val_loss: 0.8436 - val_categorical_accuracy: 0.7036
# Epoch 19/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1539 - categorical_accuracy: 0.6036 - val_loss: 0.8786 - val_categorical_accuracy: 0.6874
# Epoch 20/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1531 - categorical_accuracy: 0.6014 - val_loss: 0.8849 - val_categorical_accuracy: 0.6942
# Epoch 21/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1375 - categorical_accuracy: 0.6084 - val_loss: 0.8444 - val_categorical_accuracy: 0.6994
# Epoch 22/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1252 - categorical_accuracy: 0.6145 - val_loss: 0.8000 - val_categorical_accuracy: 0.7138
# Epoch 23/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1134 - categorical_accuracy: 0.6179 - val_loss: 0.8485 - val_categorical_accuracy: 0.7026
# Epoch 24/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.1002 - categorical_accuracy: 0.6219 - val_loss: 0.8660 - val_categorical_accuracy: 0.6976
# Epoch 25/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0940 - categorical_accuracy: 0.6268 - val_loss: 0.8149 - val_categorical_accuracy: 0.7134
# Epoch 26/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.0799 - categorical_accuracy: 0.6298 - val_loss: 0.8194 - val_categorical_accuracy: 0.7154
# Epoch 27/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0667 - categorical_accuracy: 0.6379 - val_loss: 0.8084 - val_categorical_accuracy: 0.7146
# Epoch 28/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0582 - categorical_accuracy: 0.6410 - val_loss: 0.8281 - val_categorical_accuracy: 0.7092
# Epoch 29/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0377 - categorical_accuracy: 0.6450 - val_loss: 0.7642 - val_categorical_accuracy: 0.7272
# Epoch 30/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0338 - categorical_accuracy: 0.6482 - val_loss: 0.7615 - val_categorical_accuracy: 0.7342
# Epoch 31/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0368 - categorical_accuracy: 0.6473 - val_loss: 0.7374 - val_categorical_accuracy: 0.7374
# Epoch 32/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0186 - categorical_accuracy: 0.6523 - val_loss: 0.7699 - val_categorical_accuracy: 0.7312
# Epoch 33/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0145 - categorical_accuracy: 0.6547 - val_loss: 0.7697 - val_categorical_accuracy: 0.7382
# Epoch 34/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0063 - categorical_accuracy: 0.6584 - val_loss: 0.7422 - val_categorical_accuracy: 0.7440
# Epoch 35/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0084 - categorical_accuracy: 0.6580 - val_loss: 0.7333 - val_categorical_accuracy: 0.7506
# Epoch 36/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.9929 - categorical_accuracy: 0.6629 - val_loss: 0.7339 - val_categorical_accuracy: 0.7520
# Epoch 37/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9795 - categorical_accuracy: 0.6680 - val_loss: 0.7138 - val_categorical_accuracy: 0.7570
# Epoch 38/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9781 - categorical_accuracy: 0.6678 - val_loss: 0.7284 - val_categorical_accuracy: 0.7454
# Epoch 39/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9742 - categorical_accuracy: 0.6712 - val_loss: 0.7655 - val_categorical_accuracy: 0.7434
# Epoch 40/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.9719 - categorical_accuracy: 0.6720 - val_loss: 0.7323 - val_categorical_accuracy: 0.7526
# Epoch 41/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9592 - categorical_accuracy: 0.6760 - val_loss: 0.7198 - val_categorical_accuracy: 0.7600
# Epoch 42/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9558 - categorical_accuracy: 0.6794 - val_loss: 0.7087 - val_categorical_accuracy: 0.7572
# Epoch 43/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9525 - categorical_accuracy: 0.6800 - val_loss: 0.7323 - val_categorical_accuracy: 0.7506
# Epoch 44/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9456 - categorical_accuracy: 0.6818 - val_loss: 0.6928 - val_categorical_accuracy: 0.7608
# Epoch 45/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9408 - categorical_accuracy: 0.6815 - val_loss: 0.7070 - val_categorical_accuracy: 0.7596
# Epoch 46/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9282 - categorical_accuracy: 0.6863 - val_loss: 0.6910 - val_categorical_accuracy: 0.7612
# Epoch 47/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9267 - categorical_accuracy: 0.6887 - val_loss: 0.6681 - val_categorical_accuracy: 0.7806
# Epoch 48/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.9267 - categorical_accuracy: 0.6887 - val_loss: 0.6976 - val_categorical_accuracy: 0.7642
# Epoch 49/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9226 - categorical_accuracy: 0.6904 - val_loss: 0.6883 - val_categorical_accuracy: 0.7704
# Epoch 50/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.9202 - categorical_accuracy: 0.6938 - val_loss: 0.7116 - val_categorical_accuracy: 0.7630
# Epoch 51/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9067 - categorical_accuracy: 0.6952 - val_loss: 0.6943 - val_categorical_accuracy: 0.7680
# Epoch 52/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9027 - categorical_accuracy: 0.6996 - val_loss: 0.6813 - val_categorical_accuracy: 0.7680
# Epoch 53/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8965 - categorical_accuracy: 0.6980 - val_loss: 0.6967 - val_categorical_accuracy: 0.7672
# Epoch 54/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8970 - categorical_accuracy: 0.7010 - val_loss: 0.6991 - val_categorical_accuracy: 0.7686
# Epoch 55/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8867 - categorical_accuracy: 0.7015 - val_loss: 0.6921 - val_categorical_accuracy: 0.7716
# Epoch 56/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8958 - categorical_accuracy: 0.6963 - val_loss: 0.6816 - val_categorical_accuracy: 0.7692
# Epoch 57/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8858 - categorical_accuracy: 0.7011 - val_loss: 0.7108 - val_categorical_accuracy: 0.7602
# Epoch 58/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8806 - categorical_accuracy: 0.7067 - val_loss: 0.7294 - val_categorical_accuracy: 0.7580
# Epoch 59/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8752 - categorical_accuracy: 0.7059 - val_loss: 0.6783 - val_categorical_accuracy: 0.7772
# Epoch 60/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8759 - categorical_accuracy: 0.7076 - val_loss: 0.7205 - val_categorical_accuracy: 0.7628
# Epoch 61/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8617 - categorical_accuracy: 0.7107 - val_loss: 0.6663 - val_categorical_accuracy: 0.7784
# Epoch 62/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8668 - categorical_accuracy: 0.7078 - val_loss: 0.6598 - val_categorical_accuracy: 0.7774
# Epoch 63/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8628 - categorical_accuracy: 0.7105 - val_loss: 0.6858 - val_categorical_accuracy: 0.7744
# Epoch 64/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8647 - categorical_accuracy: 0.7096 - val_loss: 0.6970 - val_categorical_accuracy: 0.7680
# Epoch 65/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8684 - categorical_accuracy: 0.7080 - val_loss: 0.6555 - val_categorical_accuracy: 0.7784
# Epoch 66/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8536 - categorical_accuracy: 0.7159 - val_loss: 0.6238 - val_categorical_accuracy: 0.7956
# Epoch 67/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8533 - categorical_accuracy: 0.7147 - val_loss: 0.6414 - val_categorical_accuracy: 0.7828
# Epoch 68/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8486 - categorical_accuracy: 0.7167 - val_loss: 0.6618 - val_categorical_accuracy: 0.7820
# Epoch 69/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8383 - categorical_accuracy: 0.7192 - val_loss: 0.6918 - val_categorical_accuracy: 0.7724
# Epoch 70/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8446 - categorical_accuracy: 0.7164 - val_loss: 0.6716 - val_categorical_accuracy: 0.7752
# Epoch 71/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8498 - categorical_accuracy: 0.7176 - val_loss: 0.6765 - val_categorical_accuracy: 0.7768
# Epoch 72/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8296 - categorical_accuracy: 0.7238 - val_loss: 0.6774 - val_categorical_accuracy: 0.7800
# Epoch 73/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8234 - categorical_accuracy: 0.7236 - val_loss: 0.6773 - val_categorical_accuracy: 0.7786
# Epoch 74/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8303 - categorical_accuracy: 0.7236 - val_loss: 0.6638 - val_categorical_accuracy: 0.7846
# Epoch 75/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8321 - categorical_accuracy: 0.7209 - val_loss: 0.6638 - val_categorical_accuracy: 0.7836
# Epoch 76/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8347 - categorical_accuracy: 0.7223 - val_loss: 0.6816 - val_categorical_accuracy: 0.7780
# Epoch 77/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8256 - categorical_accuracy: 0.7217 - val_loss: 0.6773 - val_categorical_accuracy: 0.7794
# Epoch 78/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8192 - categorical_accuracy: 0.7267 - val_loss: 0.6864 - val_categorical_accuracy: 0.7796
# Epoch 79/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8209 - categorical_accuracy: 0.7256 - val_loss: 0.6556 - val_categorical_accuracy: 0.7866
# Epoch 80/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8162 - categorical_accuracy: 0.7273 - val_loss: 0.6653 - val_categorical_accuracy: 0.7852
# Epoch 81/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8160 - categorical_accuracy: 0.7270 - val_loss: 0.6853 - val_categorical_accuracy: 0.7782
# Epoch 82/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8149 - categorical_accuracy: 0.7290 - val_loss: 0.7170 - val_categorical_accuracy: 0.7656
# Epoch 83/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8137 - categorical_accuracy: 0.7282 - val_loss: 0.6941 - val_categorical_accuracy: 0.7746
# Epoch 84/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8166 - categorical_accuracy: 0.7279 - val_loss: 0.6457 - val_categorical_accuracy: 0.7954
# Epoch 85/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8115 - categorical_accuracy: 0.7284 - val_loss: 0.6801 - val_categorical_accuracy: 0.7830
# Epoch 86/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8067 - categorical_accuracy: 0.7295 - val_loss: 0.6796 - val_categorical_accuracy: 0.7898
# Epoch 87/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8046 - categorical_accuracy: 0.7312 - val_loss: 0.6675 - val_categorical_accuracy: 0.7834
# Epoch 88/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8048 - categorical_accuracy: 0.7311 - val_loss: 0.6443 - val_categorical_accuracy: 0.7944
# Epoch 89/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8092 - categorical_accuracy: 0.7295 - val_loss: 0.6601 - val_categorical_accuracy: 0.7930
# Epoch 90/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7936 - categorical_accuracy: 0.7363 - val_loss: 0.6373 - val_categorical_accuracy: 0.7982
# Epoch 91/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8026 - categorical_accuracy: 0.7344 - val_loss: 0.6554 - val_categorical_accuracy: 0.7890
# Epoch 92/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7920 - categorical_accuracy: 0.7382 - val_loss: 0.6913 - val_categorical_accuracy: 0.7792
# Epoch 93/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7962 - categorical_accuracy: 0.7347 - val_loss: 0.6235 - val_categorical_accuracy: 0.7936
# Epoch 94/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.7870 - categorical_accuracy: 0.7377 - val_loss: 0.6503 - val_categorical_accuracy: 0.7860
# Epoch 95/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.7942 - categorical_accuracy: 0.7359 - val_loss: 0.6484 - val_categorical_accuracy: 0.7928
# Epoch 96/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7863 - categorical_accuracy: 0.7395 - val_loss: 0.6702 - val_categorical_accuracy: 0.7900
# Epoch 97/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7890 - categorical_accuracy: 0.7370 - val_loss: 0.6618 - val_categorical_accuracy: 0.7960
# Epoch 98/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.7761 - categorical_accuracy: 0.7423 - val_loss: 0.6465 - val_categorical_accuracy: 0.7918
# Epoch 99/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7992 - categorical_accuracy: 0.7354 - val_loss: 0.6544 - val_categorical_accuracy: 0.7866
# Epoch 100/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.7820 - categorical_accuracy: 0.7400 - val_loss: 0.6489 - val_categorical_accuracy: 0.7966

# %% [markdown]
# # 實驗二：使用TensorBoard超參數調校工具來訓練多個網路模型

# %% [markdown]
# ### Import必要套件：

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
# 從資料夾中的preprocessing.py檔案中Import parse_aug_fn和parse_fn函數
from preprocessing import parse_aug_fn, parse_fn

# %% [markdown]
# ### Import TensorBoard超參數工具所需要的套件

# %%
from tensorboard.plugins.hparams import api_pb2
from tensorboard.plugins.hparams import summary as hparams_summary
from google.protobuf import struct_pb2

# %% [markdown]
# ### 設定TensorBoard超參數調校

# %%
ia_list = [False, True]
bn_list = [False, True]
init_list = ['RandomNormal_0.01std',
             'glorot_normal',
             'he_normal']
lr_list = [0.001, 0.01, 0.03]

# %% [markdown]
# ### 將實驗摘要寫入紀錄檔

# %% [markdown]
# 自訂函式：創建實驗摘要，實驗摘要為Protobuffer格式，目的是讓TensorBoard HPARAMS知道有哪一些超參數和指標。

# %%
def create_experiment_summary(ia_list, bn_list, init_list, lr_list):
    ia_list_val = struct_pb2.ListValue()
    ia_list_val.extend(ia_list)
    bn_list_val = struct_pb2.ListValue()
    bn_list_val.extend(bn_list)
    init_list_val = struct_pb2.ListValue()
    init_list_val.extend(init_list)
    lr_list_val = struct_pb2.ListValue()
    lr_list_val.extend(lr_list)
    hparam_infos=[api_pb2.HParamInfo(name='ia',
                                     display_name='Imgae Augmentation',
                                     type=api_pb2.DATA_TYPE_BOOL,
                                     domain_discrete=ia_list_val),
                  api_pb2.HParamInfo(name='bn',
                                     display_name='Batch Normalization',
                                     type=api_pb2.DATA_TYPE_BOOL,
                                     domain_discrete=bn_list_val),
                  api_pb2.HParamInfo(name='init',
                                     display_name='Weight Initialization',
                                     type=api_pb2.DATA_TYPE_STRING,
                                     domain_discrete=init_list_val),
                  api_pb2.HParamInfo(name='lr',
                                     display_name='Learning Rate',
                                     type=api_pb2.DATA_TYPE_FLOAT64,
                                     domain_discrete=lr_list_val)]
    metric_infos=[api_pb2.MetricInfo(name=api_pb2.MetricName(tag='Accuracy'),
                                     display_name='Accuracy')]
    return hparams_summary.experiment_pb(hparam_infos, metric_infos)

# %% [markdown]
# 將實驗摘要寫到記錄檔中：

# %%
# 創建Protobuffer格式的實驗摘要(超參數和指標)
exp_summary = create_experiment_summary(ia_list, bn_list, init_list, lr_list)
# 創建TensorBoard logs檔
root_logdir_writer = tf.summary.create_file_writer("lab7-logs-hparams/hparam_tuning")
with root_logdir_writer.as_default():  # root_logdir_writer作為預設寫入的紀錄檔
    # 將Protobuffer格式的實驗摘要轉成TensorBoard事件格式
    event = tf.compat.v1.Event(summary=exp_summary).SerializeToString()
    tf.summary.import_event(event)  # 將事件寫入記錄檔中

# %% [markdown]
# ### 訓練網路模型

# %% [markdown]
# 準備訓練資料，分別為「沒有影像增強」和「有影像增強」的訓練資料

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE  # 自動調整模式
batch_size = 64  # 批次大小
train_num = int(info.splits['train'].num_examples / 5) * 4  # 訓練資料數量


# 取得訓練數據
train_data_noaug = tfds.load("cifar10", split=train_split)
train_data_aug = tfds.load("cifar10", split=train_split)

train_data_noaug = train_data_noaug.shuffle(train_num)  # 打散資料集
# 載入預處理「 parse_aug_fn」function，cpu數量為自動調整模式
train_data_noaug = train_data_noaug.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
train_data_noaug = train_data_noaug.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

train_data_aug = train_data_aug.shuffle(train_num)  # 打散資料集
# 載入預處理「 parse_fn」function，cpu數量為自動調整模式
train_data_aug = train_data_aug.map(map_func=parse_aug_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
train_data_aug = train_data_aug.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# 客製化超參數回調函式：用於紀錄每一次訓練模型的超參數數值和最終訓練結果的指標值。

# %%
class HyperparameterCallback(tf.keras.callbacks.Callback):
    # 類別創建時調用
    def __init__(self, log_dir, hparams):
        super(HyperparameterCallback, self).__init__()
        self.log_dir = log_dir
        self.hparams = hparams
        self.best_accuracy = 0
        self.writer = None
    # 訓練開始前調用
    def on_train_begin(self, logs=None):
        self.writer = tf.summary.create_file_writer(self.log_dir)
        summary_start = hparams_summary.session_start_pb(hparams=self.hparams)
        start_event = tf.compat.v1.Event(summary=summary_start).SerializeToString()
        with self.writer.as_default():
            tf.summary.import_event(start_event)
    # 每一個Epcoh結束後調用
    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('val_categorical_accuracy')
        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
    # 訓練結束時調用
    def on_train_end(self, logs=None):
        summary_end = hparams_summary.session_end_pb(api_pb2.STATUS_SUCCESS)
        end_event = tf.compat.v1.Event(summary=summary_end).SerializeToString()
        with self.writer.as_default():
            tf.summary.scalar('Accuracy', self.best_accuracy, step=0)
            tf.summary.import_event(end_event)

# %% [markdown]
# 建立一個函式負責創建、編譯和訓練網路模型，網路層配置如下：
# - keras.Input：輸入層(輸入影像大小為32x32x3)。
# - layers.Conv2D：卷積層(使用ReLU激活函數，以及3x3大小的kernel)。
# - layers.MaxPool2D：池化層(對特徵圖下採樣)。
# - layers.Flatten：扁平層(特徵圖轉成一維Tensor)。
# - layers.Dropout：Dropout層(每次訓練隨機丟棄50%網路)。
# - layers.Dense：全連接層(隱藏層使用ReLU激活函數，輸出層使用Softmax激活函數)。

# %%
def train_test_model(logs_dir, hparams):
    """
    logs_dir:傳入目前執行的任務log檔的位置
    hparams:傳入超參數
    """
    # 指派網路模型初始化的方法
    if hparams['init'] == "glorot_normal":
        init = initializers.glorot_normal()
    elif hparams['init'] == "he_normal":
        init = initializers.he_normal()
    else:
        init = initializers.RandomNormal(0, 0.01)

    inputs = keras.Input(shape=(32, 32, 3))
    x = layers.Conv2D(64, (3, 3), kernel_initializer=init)(inputs)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Conv2D(128, (3, 3), kernel_initializer=init)(x)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(256, (3, 3), kernel_initializer=init)(x)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(128, (3, 3), kernel_initializer=init)(x)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(64, (3, 3), kernel_initializer=init)(x)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, kernel_initializer=init)(x)
    if hparams['bn']: x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(10, activation='softmax')(x)
    # 建立網路模型(將輸入到輸出所有經過的網路層連接起來)
    model = keras.Model(inputs, outputs, name='model')

    # 儲存訓練記錄檔
    model_tb = keras.callbacks.TensorBoard(log_dir=logs_dir, write_graph=False)

    # 儲存最好的網路模型權重
    model_mckp = keras.callbacks.ModelCheckpoint(logs_dir +'/best-model.hdf5', 
                                                 monitor='val_categorical_accuracy', 
                                                 save_best_only=True, 
                                                 mode='max')
    
    # 設定停止訓練的條件(當Accuracy超過30迭代沒有上升的話訓練會終止)
    model_els = keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy' , 
                                              min_delta=0, 
                                              patience=30, 
                                              mode='max')
    # 客自化超參數回調函式，紀錄訓練模型的超參數和指標(準確率)
    model_hparam = HyperparameterCallback(logs_dir + 'validation', hparams)


    # 設定訓練使用的優化器、損失函數和指標函數
    # 優化器學習率為超參數：0.001、0.01或0.03
    model.compile(keras.optimizers.Adam(hparams['lr']), 
                  loss=keras.losses.CategoricalCrossentropy(), 
                  metrics=[keras.metrics.CategoricalAccuracy()])
    
    # 超參數：使用「經過影像增強的數據」或「不經過影像增強的數據」訓練網路
    if hparams['ia']:
        history = model.fit(train_data_aug,
                            epochs=100, 
                            validation_data=valid_data,
                            callbacks=[model_tb, model_mckp, model_els, model_hparam])
    else:
        history = model.fit(train_data_noaug,
                            epochs=100, 
                            validation_data=valid_data,
                            callbacks=[model_tb, model_mckp, model_els, model_hparam])

# %% [markdown]
# 訓練36種不同參數的網路模型：

# %%
session_id = 1  # 訓練任務的id
for ia in ia_list:
    for bn in bn_list:
        for init in init_list:
            for lr in lr_list:
                # 顯示目前訓練任務id
                print('--- Running training session {}'.format(session_id))
                # 設定本次訓練的超參數
                hparams = {'ia': ia, 'bn': bn, 'init': init, 'lr': lr}
                # 儲放紀錄檔的位置
                logs_dir = "lab7-logs-hparams/run-{}".format(session_id)
                # 建立、編譯及訓練網路模型
                train_test_model(logs_dir, hparams)
                session_id += 1  # id+1
# Out:
# --- Running training session 1
# Epoch 1/100
#       1/Unknown - 12s 12s/step - loss: 2.3026 - categorical_accuracy: 0.0625
# WARNING: Logging before flag parsing goes to stderr.
# W0423 14:11:27.514188 140303049860864 callbacks.py:236] Method (on_train_batch_end) is slow compared to the batch update (0.192300). Check your callbacks.
# 704/704 [==============================] - 23s 33ms/step - loss: 2.1177 - categorical_accuracy: 0.1981 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 21s 30ms/step - loss: 1.9106 - categorical_accuracy: 0.2809 - val_loss: 1.7897 - val_categorical_accuracy: 0.3300
# Epoch 3/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.8074 - categorical_accuracy: 0.3233 - val_loss: 1.6816 - val_categorical_accuracy: 0.3842
# Epoch 4/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.7261 - categorical_accuracy: 0.3523 - val_loss: 1.5660 - val_categorical_accuracy: 0.4282
# Epoch 5/100
# 704/704 [==============================] - 21s 30ms/step - loss: 1.6565 - categorical_accuracy: 0.3870 - val_loss: 1.4883 - val_categorical_accuracy: 0.4610
# Epoch 6/100
# 704/704 [==============================] - 22s 31ms/step - loss: 1.6009 - categorical_accuracy: 0.4085 - val_loss: 1.4367 - val_categorical_accuracy: 0.4802
# Epoch 7/100
# 704/704 [==============================] - 19s 27ms/step - loss: 1.5570 - categorical_accuracy: 0.4233 - val_loss: 1.3943 - val_categorical_accuracy: 0.4888
# Epoch 8/100
# 704/704 [==============================] - 21s 30ms/step - loss: 1.5122 - categorical_accuracy: 0.4409 - val_loss: 1.3324 - val_categorical_accuracy: 0.5122
# Epoch 9/100
# 704/704 [==============================] - 19s 28ms/step - loss: 1.4624 - categorical_accuracy: 0.4601 - val_loss: 1.3385 - val_categorical_accuracy: 0.5064
# Epoch 10/100
# 704/704 [==============================] - 18s 25ms/step - loss: 1.4340 - categorical_accuracy: 0.4744 - val_loss: 1.2818 - val_categorical_accuracy: 0.5290
# Epoch 11/100
# 704/704 [==============================] - 19s 26ms/step - loss: 1.4058 - categorical_accuracy: 0.4860 - val_loss: 1.2663 - val_categorical_accuracy: 0.5398
# Epoch 12/100
# 704/704 [==============================] - 20s 28ms/step - loss: 1.3830 - categorical_accuracy: 0.4939 - val_loss: 1.2476 - val_categorical_accuracy: 0.5414
# Epoch 13/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.3597 - categorical_accuracy: 0.4983 - val_loss: 1.2359 - val_categorical_accuracy: 0.5460
# Epoch 14/100
# 704/704 [==============================] - 20s 29ms/step - loss: 1.3332 - categorical_accuracy: 0.5111 - val_loss: 1.2015 - val_categorical_accuracy: 0.5586
# Epoch 15/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.3124 - categorical_accuracy: 0.5199 - val_loss: 1.1861 - val_categorical_accuracy: 0.5630
# Epoch 16/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.2896 - categorical_accuracy: 0.5270 - val_loss: 1.1873 - val_categorical_accuracy: 0.5540
# Epoch 17/100
# 704/704 [==============================] - 17s 25ms/step - loss: 1.2656 - categorical_accuracy: 0.5394 - val_loss: 1.1643 - val_categorical_accuracy: 0.5722
# Epoch 18/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.2528 - categorical_accuracy: 0.5436 - val_loss: 1.1877 - val_categorical_accuracy: 0.5642
# Epoch 19/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.2349 - categorical_accuracy: 0.5483 - val_loss: 1.1629 - val_categorical_accuracy: 0.5714
# Epoch 20/100
# 704/704 [==============================] - 17s 25ms/step - loss: 1.2250 - categorical_accuracy: 0.5518 - val_loss: 1.2051 - val_categorical_accuracy: 0.5614
# Epoch 21/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.2077 - categorical_accuracy: 0.5562 - val_loss: 1.1801 - val_categorical_accuracy: 0.5658
# Epoch 22/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.1905 - categorical_accuracy: 0.5622 - val_loss: 1.2027 - val_categorical_accuracy: 0.5614
# Epoch 23/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.1721 - categorical_accuracy: 0.5669 - val_loss: 1.1526 - val_categorical_accuracy: 0.5816
# Epoch 24/100
# 704/704 [==============================] - 15s 22ms/step - loss: 1.1604 - categorical_accuracy: 0.5744 - val_loss: 1.1729 - val_categorical_accuracy: 0.5854
# Epoch 25/100
# 704/704 [==============================] - 15s 22ms/step - loss: 1.1495 - categorical_accuracy: 0.5781 - val_loss: 1.1692 - val_categorical_accuracy: 0.5802
# Epoch 26/100
# 704/704 [==============================] - 15s 22ms/step - loss: 1.1333 - categorical_accuracy: 0.5834 - val_loss: 1.1729 - val_categorical_accuracy: 0.5922
# Epoch 27/100
# 704/704 [==============================] - 15s 22ms/step - loss: 1.1192 - categorical_accuracy: 0.5923 - val_loss: 1.1430 - val_categorical_accuracy: 0.5856
# Epoch 28/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.0953 - categorical_accuracy: 0.5961 - val_loss: 1.1511 - val_categorical_accuracy: 0.5880
# Epoch 29/100
# 704/704 [==============================] - 14s 21ms/step - loss: 1.0830 - categorical_accuracy: 0.6014 - val_loss: 1.1587 - val_categorical_accuracy: 0.5880
# Epoch 30/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.0734 - categorical_accuracy: 0.6045 - val_loss: 1.1851 - val_categorical_accuracy: 0.5916
# Epoch 31/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.0553 - categorical_accuracy: 0.6098 - val_loss: 1.1519 - val_categorical_accuracy: 0.5982
# Epoch 32/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.0489 - categorical_accuracy: 0.6137 - val_loss: 1.1662 - val_categorical_accuracy: 0.5950
# Epoch 33/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.0404 - categorical_accuracy: 0.6152 - val_loss: 1.1417 - val_categorical_accuracy: 0.6014
# Epoch 34/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.0238 - categorical_accuracy: 0.6189 - val_loss: 1.1624 - val_categorical_accuracy: 0.5938
# Epoch 35/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.0146 - categorical_accuracy: 0.6234 - val_loss: 1.1582 - val_categorical_accuracy: 0.6026
# Epoch 36/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.0112 - categorical_accuracy: 0.6269 - val_loss: 1.1753 - val_categorical_accuracy: 0.5986
# Epoch 37/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9968 - categorical_accuracy: 0.6308 - val_loss: 1.1596 - val_categorical_accuracy: 0.6030
# Epoch 38/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9758 - categorical_accuracy: 0.6387 - val_loss: 1.2236 - val_categorical_accuracy: 0.6020
# Epoch 39/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.9652 - categorical_accuracy: 0.6408 - val_loss: 1.1747 - val_categorical_accuracy: 0.6060
# Epoch 40/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9552 - categorical_accuracy: 0.6421 - val_loss: 1.2063 - val_categorical_accuracy: 0.6094
# Epoch 41/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.9500 - categorical_accuracy: 0.6441 - val_loss: 1.1998 - val_categorical_accuracy: 0.6046
# Epoch 42/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.9403 - categorical_accuracy: 0.6510 - val_loss: 1.2170 - val_categorical_accuracy: 0.5984
# Epoch 43/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.9309 - categorical_accuracy: 0.6505 - val_loss: 1.2687 - val_categorical_accuracy: 0.5966
# Epoch 44/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.9199 - categorical_accuracy: 0.6544 - val_loss: 1.2151 - val_categorical_accuracy: 0.6076
# Epoch 45/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.9092 - categorical_accuracy: 0.6566 - val_loss: 1.2890 - val_categorical_accuracy: 0.5960
# Epoch 46/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8991 - categorical_accuracy: 0.6628 - val_loss: 1.2881 - val_categorical_accuracy: 0.5958
# Epoch 47/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.8882 - categorical_accuracy: 0.6648 - val_loss: 1.2834 - val_categorical_accuracy: 0.5980
# Epoch 48/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.8809 - categorical_accuracy: 0.6665 - val_loss: 1.2783 - val_categorical_accuracy: 0.6016
# Epoch 49/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.8725 - categorical_accuracy: 0.6701 - val_loss: 1.2755 - val_categorical_accuracy: 0.6070
# Epoch 50/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.8663 - categorical_accuracy: 0.6737 - val_loss: 1.2980 - val_categorical_accuracy: 0.6046
# Epoch 51/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.8500 - categorical_accuracy: 0.6755 - val_loss: 1.3561 - val_categorical_accuracy: 0.6104
# Epoch 52/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8472 - categorical_accuracy: 0.6781 - val_loss: 1.3784 - val_categorical_accuracy: 0.6008
# Epoch 53/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8343 - categorical_accuracy: 0.6832 - val_loss: 1.3258 - val_categorical_accuracy: 0.6074
# Epoch 54/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8273 - categorical_accuracy: 0.6864 - val_loss: 1.3682 - val_categorical_accuracy: 0.6060
# Epoch 55/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.8228 - categorical_accuracy: 0.6878 - val_loss: 1.3839 - val_categorical_accuracy: 0.6084
# Epoch 56/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8067 - categorical_accuracy: 0.6894 - val_loss: 1.3828 - val_categorical_accuracy: 0.6072
# Epoch 57/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.7951 - categorical_accuracy: 0.6970 - val_loss: 1.4641 - val_categorical_accuracy: 0.5986
# Epoch 58/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.7900 - categorical_accuracy: 0.6980 - val_loss: 1.3971 - val_categorical_accuracy: 0.6096
# Epoch 59/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.7784 - categorical_accuracy: 0.7010 - val_loss: 1.3891 - val_categorical_accuracy: 0.5968
# Epoch 60/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.7856 - categorical_accuracy: 0.6959 - val_loss: 1.4677 - val_categorical_accuracy: 0.6046
# Epoch 61/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.7648 - categorical_accuracy: 0.7044 - val_loss: 1.4282 - val_categorical_accuracy: 0.6088
# Epoch 62/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.7593 - categorical_accuracy: 0.7074 - val_loss: 1.5282 - val_categorical_accuracy: 0.5992
# Epoch 63/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7543 - categorical_accuracy: 0.7096 - val_loss: 1.5402 - val_categorical_accuracy: 0.5980
# Epoch 64/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7450 - categorical_accuracy: 0.7123 - val_loss: 1.5296 - val_categorical_accuracy: 0.5948
# Epoch 65/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.7423 - categorical_accuracy: 0.7121 - val_loss: 1.4886 - val_categorical_accuracy: 0.6082
# Epoch 66/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.7348 - categorical_accuracy: 0.7156 - val_loss: 1.4906 - val_categorical_accuracy: 0.6046
# Epoch 67/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7343 - categorical_accuracy: 0.7161 - val_loss: 1.5149 - val_categorical_accuracy: 0.6120
# Epoch 68/100
# 704/704 [==============================] - 20s 28ms/step - loss: 0.7261 - categorical_accuracy: 0.7186 - val_loss: 1.5244 - val_categorical_accuracy: 0.6000
# Epoch 69/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.7095 - categorical_accuracy: 0.7251 - val_loss: 1.5344 - val_categorical_accuracy: 0.6080
# Epoch 70/100
# 704/704 [==============================] - 20s 29ms/step - loss: 0.7216 - categorical_accuracy: 0.7216 - val_loss: 1.6314 - val_categorical_accuracy: 0.5984
# Epoch 71/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6987 - categorical_accuracy: 0.7274 - val_loss: 1.5954 - val_categorical_accuracy: 0.6008
# Epoch 72/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.6972 - categorical_accuracy: 0.7280 - val_loss: 1.6154 - val_categorical_accuracy: 0.5992
# Epoch 73/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.7084 - categorical_accuracy: 0.7261 - val_loss: 1.5602 - val_categorical_accuracy: 0.5968
# Epoch 74/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6926 - categorical_accuracy: 0.7298 - val_loss: 1.6330 - val_categorical_accuracy: 0.5940
# Epoch 75/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.6852 - categorical_accuracy: 0.7314 - val_loss: 1.6874 - val_categorical_accuracy: 0.6042
# Epoch 76/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.6946 - categorical_accuracy: 0.7300 - val_loss: 1.6421 - val_categorical_accuracy: 0.6048
# Epoch 77/100
# 704/704 [==============================] - 17s 23ms/step - loss: 0.6765 - categorical_accuracy: 0.7381 - val_loss: 1.5851 - val_categorical_accuracy: 0.6020
# Epoch 78/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6777 - categorical_accuracy: 0.7361 - val_loss: 1.6169 - val_categorical_accuracy: 0.6058
# Epoch 79/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6702 - categorical_accuracy: 0.7365 - val_loss: 1.7175 - val_categorical_accuracy: 0.5970
# Epoch 80/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.6623 - categorical_accuracy: 0.7395 - val_loss: 1.6811 - val_categorical_accuracy: 0.6014
# Epoch 81/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6629 - categorical_accuracy: 0.7381 - val_loss: 1.6508 - val_categorical_accuracy: 0.6030
# Epoch 82/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6592 - categorical_accuracy: 0.7423 - val_loss: 1.7176 - val_categorical_accuracy: 0.6000
# Epoch 83/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.6548 - categorical_accuracy: 0.7443 - val_loss: 1.6907 - val_categorical_accuracy: 0.6028
# Epoch 84/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6583 - categorical_accuracy: 0.7440 - val_loss: 1.6871 - val_categorical_accuracy: 0.5996
# Epoch 85/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.6542 - categorical_accuracy: 0.7445 - val_loss: 1.8370 - val_categorical_accuracy: 0.5930
# Epoch 86/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.6420 - categorical_accuracy: 0.7504 - val_loss: 1.7410 - val_categorical_accuracy: 0.6028
# Epoch 87/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.6373 - categorical_accuracy: 0.7496 - val_loss: 1.7843 - val_categorical_accuracy: 0.5996
# Epoch 88/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.6353 - categorical_accuracy: 0.7508 - val_loss: 1.8351 - val_categorical_accuracy: 0.5992
# Epoch 89/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6366 - categorical_accuracy: 0.7492 - val_loss: 1.7823 - val_categorical_accuracy: 0.6004
# Epoch 90/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6307 - categorical_accuracy: 0.7534 - val_loss: 1.8504 - val_categorical_accuracy: 0.5954
# Epoch 91/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.6263 - categorical_accuracy: 0.7544 - val_loss: 1.8443 - val_categorical_accuracy: 0.6038
# Epoch 92/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6223 - categorical_accuracy: 0.7555 - val_loss: 1.8228 - val_categorical_accuracy: 0.5984
# Epoch 93/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.6118 - categorical_accuracy: 0.7609 - val_loss: 1.8869 - val_categorical_accuracy: 0.5976
# Epoch 94/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.6050 - categorical_accuracy: 0.7636 - val_loss: 2.0015 - val_categorical_accuracy: 0.5922
# Epoch 95/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.6082 - categorical_accuracy: 0.7625 - val_loss: 1.9687 - val_categorical_accuracy: 0.5894
# Epoch 96/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.5985 - categorical_accuracy: 0.7651 - val_loss: 1.9772 - val_categorical_accuracy: 0.5880
# Epoch 97/100
# 704/704 [==============================] - 20s 29ms/step - loss: 0.6056 - categorical_accuracy: 0.7634 - val_loss: 1.9225 - val_categorical_accuracy: 0.5884
# --- Running training session 2
# Epoch 1/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3087 - categorical_accuracy: 0.1011 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1014 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 3/100
# 704/704 [==============================] - 18s 26ms/step - loss: 2.3035 - categorical_accuracy: 0.1015 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 4/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1015 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 5/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 6/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 7/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 8/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 9/100
# 704/704 [==============================] - 19s 28ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 10/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 11/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 12/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 13/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 14/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 15/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 16/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 17/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 18/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 19/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 20/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 21/100
# 704/704 [==============================] - 14s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 22/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 23/100
# 704/704 [==============================] - 18s 26ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 24/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 25/100
# 704/704 [==============================] - 18s 26ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 26/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 27/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 28/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 29/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 30/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 31/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# --- Running training session 3
# Epoch 1/100
# 704/704 [==============================] - 15s 21ms/step - loss: 3.3538 - categorical_accuracy: 0.1038 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3048 - categorical_accuracy: 0.1039 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 3/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3048 - categorical_accuracy: 0.1038 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 4/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1038 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 5/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1038 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 6/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1038 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 7/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 8/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 9/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 10/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 11/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 12/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 13/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 14/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 15/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 16/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 17/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 18/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 19/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 20/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 21/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 22/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 23/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 24/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 25/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 26/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 27/100
# 704/704 [==============================] - 19s 28ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 28/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 29/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 30/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 31/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# --- Running training session 4
# Epoch 1/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.9055 - categorical_accuracy: 0.2754 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 20s 28ms/step - loss: 1.5714 - categorical_accuracy: 0.4204 - val_loss: 1.3370 - val_categorical_accuracy: 0.5078
# Epoch 3/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.4065 - categorical_accuracy: 0.4924 - val_loss: 1.2398 - val_categorical_accuracy: 0.5498
# Epoch 4/100
# 704/704 [==============================] - 16s 23ms/step - loss: 1.2897 - categorical_accuracy: 0.5390 - val_loss: 1.1276 - val_categorical_accuracy: 0.5870
# Epoch 5/100
# 704/704 [==============================] - 17s 25ms/step - loss: 1.1865 - categorical_accuracy: 0.5776 - val_loss: 1.0690 - val_categorical_accuracy: 0.6124
# Epoch 6/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.1055 - categorical_accuracy: 0.6103 - val_loss: 1.0275 - val_categorical_accuracy: 0.6310
# Epoch 7/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.0295 - categorical_accuracy: 0.6381 - val_loss: 0.9734 - val_categorical_accuracy: 0.6612
# Epoch 8/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9606 - categorical_accuracy: 0.6610 - val_loss: 0.9278 - val_categorical_accuracy: 0.6772
# Epoch 9/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.9111 - categorical_accuracy: 0.6792 - val_loss: 1.0047 - val_categorical_accuracy: 0.6546
# Epoch 10/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.8616 - categorical_accuracy: 0.6935 - val_loss: 0.9572 - val_categorical_accuracy: 0.6752
# Epoch 11/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.8106 - categorical_accuracy: 0.7135 - val_loss: 0.9513 - val_categorical_accuracy: 0.6872
# Epoch 12/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7705 - categorical_accuracy: 0.7264 - val_loss: 0.9849 - val_categorical_accuracy: 0.6922
# Epoch 13/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7310 - categorical_accuracy: 0.7390 - val_loss: 0.9947 - val_categorical_accuracy: 0.6886
# Epoch 14/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6878 - categorical_accuracy: 0.7546 - val_loss: 0.9443 - val_categorical_accuracy: 0.7076
# Epoch 15/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6494 - categorical_accuracy: 0.7695 - val_loss: 1.0326 - val_categorical_accuracy: 0.7008
# Epoch 16/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.6206 - categorical_accuracy: 0.7790 - val_loss: 1.0007 - val_categorical_accuracy: 0.7106
# Epoch 17/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.5866 - categorical_accuracy: 0.7918 - val_loss: 1.0610 - val_categorical_accuracy: 0.7084
# Epoch 18/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.5687 - categorical_accuracy: 0.7952 - val_loss: 1.0866 - val_categorical_accuracy: 0.7118
# Epoch 19/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.5339 - categorical_accuracy: 0.8109 - val_loss: 1.0881 - val_categorical_accuracy: 0.7100
# Epoch 20/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.5064 - categorical_accuracy: 0.8179 - val_loss: 1.2089 - val_categorical_accuracy: 0.6988
# Epoch 21/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4808 - categorical_accuracy: 0.8289 - val_loss: 1.1790 - val_categorical_accuracy: 0.7142
# Epoch 22/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4551 - categorical_accuracy: 0.8382 - val_loss: 1.2702 - val_categorical_accuracy: 0.7004
# Epoch 23/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.4299 - categorical_accuracy: 0.8458 - val_loss: 1.3953 - val_categorical_accuracy: 0.7030
# Epoch 24/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.4262 - categorical_accuracy: 0.8502 - val_loss: 1.3318 - val_categorical_accuracy: 0.7090
# Epoch 25/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.4023 - categorical_accuracy: 0.8579 - val_loss: 1.4344 - val_categorical_accuracy: 0.7120
# Epoch 26/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4042 - categorical_accuracy: 0.8581 - val_loss: 1.3323 - val_categorical_accuracy: 0.7190
# Epoch 27/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.3646 - categorical_accuracy: 0.8720 - val_loss: 1.3342 - val_categorical_accuracy: 0.7176
# Epoch 28/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.3510 - categorical_accuracy: 0.8769 - val_loss: 1.3574 - val_categorical_accuracy: 0.7196
# Epoch 29/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.3264 - categorical_accuracy: 0.8846 - val_loss: 1.3685 - val_categorical_accuracy: 0.7198
# Epoch 30/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.3273 - categorical_accuracy: 0.8873 - val_loss: 1.4423 - val_categorical_accuracy: 0.7108
# Epoch 31/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.3008 - categorical_accuracy: 0.8947 - val_loss: 1.4657 - val_categorical_accuracy: 0.7242
# Epoch 32/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.2919 - categorical_accuracy: 0.9005 - val_loss: 1.4442 - val_categorical_accuracy: 0.7230
# Epoch 33/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.2755 - categorical_accuracy: 0.9048 - val_loss: 1.6222 - val_categorical_accuracy: 0.7100
# Epoch 34/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.2612 - categorical_accuracy: 0.9087 - val_loss: 1.6809 - val_categorical_accuracy: 0.7122
# Epoch 35/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.2609 - categorical_accuracy: 0.9134 - val_loss: 1.4529 - val_categorical_accuracy: 0.7202
# Epoch 36/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.2402 - categorical_accuracy: 0.9164 - val_loss: 1.8888 - val_categorical_accuracy: 0.7026
# Epoch 37/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.2361 - categorical_accuracy: 0.9202 - val_loss: 1.6141 - val_categorical_accuracy: 0.7196
# Epoch 38/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.2294 - categorical_accuracy: 0.9240 - val_loss: 1.6579 - val_categorical_accuracy: 0.7262
# Epoch 39/100
# 704/704 [==============================] - 21s 29ms/step - loss: 0.2239 - categorical_accuracy: 0.9252 - val_loss: 1.8094 - val_categorical_accuracy: 0.7142
# Epoch 40/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.2256 - categorical_accuracy: 0.9260 - val_loss: 1.6316 - val_categorical_accuracy: 0.7216
# Epoch 41/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.2096 - categorical_accuracy: 0.9307 - val_loss: 1.7704 - val_categorical_accuracy: 0.7138
# Epoch 42/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1942 - categorical_accuracy: 0.9351 - val_loss: 1.9234 - val_categorical_accuracy: 0.7150
# Epoch 43/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1955 - categorical_accuracy: 0.9352 - val_loss: 1.7876 - val_categorical_accuracy: 0.7184
# Epoch 44/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.1936 - categorical_accuracy: 0.9374 - val_loss: 1.8239 - val_categorical_accuracy: 0.7186
# Epoch 45/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.1847 - categorical_accuracy: 0.9402 - val_loss: 1.8491 - val_categorical_accuracy: 0.7132
# Epoch 46/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1778 - categorical_accuracy: 0.9427 - val_loss: 1.9974 - val_categorical_accuracy: 0.7204
# Epoch 47/100
# 704/704 [==============================] - 20s 28ms/step - loss: 0.1728 - categorical_accuracy: 0.9438 - val_loss: 1.8972 - val_categorical_accuracy: 0.7170
# Epoch 48/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1720 - categorical_accuracy: 0.9459 - val_loss: 1.9343 - val_categorical_accuracy: 0.7140
# Epoch 49/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.1726 - categorical_accuracy: 0.9448 - val_loss: 1.9265 - val_categorical_accuracy: 0.7178
# Epoch 50/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1548 - categorical_accuracy: 0.9487 - val_loss: 1.8954 - val_categorical_accuracy: 0.7196
# Epoch 51/100
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1671 - categorical_accuracy: 0.9476 - val_loss: 1.9679 - val_categorical_accuracy: 0.7072
# Epoch 52/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.1584 - categorical_accuracy: 0.9503 - val_loss: 1.9570 - val_categorical_accuracy: 0.7134
# Epoch 53/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.1547 - categorical_accuracy: 0.9494 - val_loss: 2.1521 - val_categorical_accuracy: 0.7222
# Epoch 54/100
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1426 - categorical_accuracy: 0.9547 - val_loss: 2.2010 - val_categorical_accuracy: 0.7148
# Epoch 55/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.1457 - categorical_accuracy: 0.9542 - val_loss: 2.2607 - val_categorical_accuracy: 0.7146
# Epoch 56/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.1440 - categorical_accuracy: 0.9551 - val_loss: 2.1199 - val_categorical_accuracy: 0.7208
# Epoch 57/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.1425 - categorical_accuracy: 0.9544 - val_loss: 2.1831 - val_categorical_accuracy: 0.7188
# Epoch 58/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.1422 - categorical_accuracy: 0.9557 - val_loss: 2.2095 - val_categorical_accuracy: 0.7072
# Epoch 59/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.1389 - categorical_accuracy: 0.9567 - val_loss: 2.1922 - val_categorical_accuracy: 0.7256
# Epoch 60/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.1366 - categorical_accuracy: 0.9568 - val_loss: 2.3858 - val_categorical_accuracy: 0.7100
# Epoch 61/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1413 - categorical_accuracy: 0.9568 - val_loss: 2.3578 - val_categorical_accuracy: 0.7150
# Epoch 62/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.1249 - categorical_accuracy: 0.9616 - val_loss: 2.4344 - val_categorical_accuracy: 0.7238
# Epoch 63/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.1222 - categorical_accuracy: 0.9611 - val_loss: 2.4289 - val_categorical_accuracy: 0.7188
# Epoch 64/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1418 - categorical_accuracy: 0.9569 - val_loss: 2.3315 - val_categorical_accuracy: 0.7218
# Epoch 65/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.1384 - categorical_accuracy: 0.9574 - val_loss: 2.2657 - val_categorical_accuracy: 0.7148
# Epoch 66/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.1191 - categorical_accuracy: 0.9631 - val_loss: 2.4449 - val_categorical_accuracy: 0.7126
# Epoch 67/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.1226 - categorical_accuracy: 0.9612 - val_loss: 2.4675 - val_categorical_accuracy: 0.7136
# Epoch 68/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.1156 - categorical_accuracy: 0.9645 - val_loss: 2.3150 - val_categorical_accuracy: 0.7216
# --- Running training session 5
# Epoch 1/100
# 704/704 [==============================] - 14s 20ms/step - loss: 3.0691 - categorical_accuracy: 0.1017 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3035 - categorical_accuracy: 0.1017 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 3/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1017 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 4/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 5/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 6/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 7/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 8/100
# 704/704 [==============================] - 13s 18ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 9/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 10/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 11/100
# 704/704 [==============================] - 15s 22ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 12/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 13/100
# 704/704 [==============================] - 16s 22ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 14/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 15/100
# 704/704 [==============================] - 20s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 16/100
# 704/704 [==============================] - 20s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 17/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 18/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 19/100
# 704/704 [==============================] - 21s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 20/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 21/100
# 704/704 [==============================] - 18s 25ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 22/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 23/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 24/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 25/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 26/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 27/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 28/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 29/100
# 704/704 [==============================] - 20s 29ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 30/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# Epoch 31/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3035 - categorical_accuracy: 0.1016 - val_loss: 2.3024 - val_categorical_accuracy: 0.1038
# --- Running training session 6
# Epoch 1/100
# 704/704 [==============================] - 15s 21ms/step - loss: 23.2937 - categorical_accuracy: 0.1033 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 704/704 [==============================] - 21s 30ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 3/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3048 - categorical_accuracy: 0.1039 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 4/100
# 704/704 [==============================] - 18s 26ms/step - loss: 2.3048 - categorical_accuracy: 0.1039 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 5/100
# 704/704 [==============================] - 14s 20ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 6/100
# 704/704 [==============================] - 16s 23ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 7/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 8/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 9/100
# 704/704 [==============================] - 19s 27ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 10/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 11/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 12/100
# 704/704 [==============================] - 15s 21ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 13/100
# 704/704 [==============================] - 17s 25ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 14/100
# 704/704 [==============================] - 18s 25ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 15/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 16/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 17/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 18/100
# 704/704 [==============================] - 15s 22ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 19/100
# 704/704 [==============================] - 14s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 20/100
# 704/704 [==============================] - 13s 19ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 21/100
# 704/704 [==============================] - 17s 24ms/step - loss: 2.3048 - categorical_accuracy: 0.1037 - val_loss: 2.3037 - val_categorical_accuracy: 0.1038
# Epoch 22/100
# ...
# Epoch 7/100
# 704/704 [==============================] - 18s 25ms/step - loss: 1.4191 - categorical_accuracy: 0.4937 - val_loss: 1.1598 - val_categorical_accuracy: 0.5930
# Epoch 8/100
# 704/704 [==============================] - 17s 25ms/step - loss: 1.3733 - categorical_accuracy: 0.5181 - val_loss: 1.0365 - val_categorical_accuracy: 0.6124
# Epoch 9/100
# 704/704 [==============================] - 17s 25ms/step - loss: 1.3231 - categorical_accuracy: 0.5381 - val_loss: 1.3194 - val_categorical_accuracy: 0.5732
# Epoch 10/100
# 704/704 [==============================] - 19s 27ms/step - loss: 1.2806 - categorical_accuracy: 0.5556 - val_loss: 0.8927 - val_categorical_accuracy: 0.6862
# Epoch 11/100
# 704/704 [==============================] - 18s 25ms/step - loss: 1.2601 - categorical_accuracy: 0.5653 - val_loss: 1.3346 - val_categorical_accuracy: 0.5674
# Epoch 12/100
# 704/704 [==============================] - 19s 27ms/step - loss: 1.2253 - categorical_accuracy: 0.5775 - val_loss: 0.9324 - val_categorical_accuracy: 0.6730
# Epoch 13/100
# 704/704 [==============================] - 19s 27ms/step - loss: 1.1986 - categorical_accuracy: 0.5876 - val_loss: 0.9931 - val_categorical_accuracy: 0.6520
# Epoch 14/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.1673 - categorical_accuracy: 0.5964 - val_loss: 0.8943 - val_categorical_accuracy: 0.6968
# Epoch 15/100
# 704/704 [==============================] - 21s 30ms/step - loss: 1.1418 - categorical_accuracy: 0.6097 - val_loss: 0.8642 - val_categorical_accuracy: 0.6946
# Epoch 16/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.1263 - categorical_accuracy: 0.6142 - val_loss: 0.8741 - val_categorical_accuracy: 0.7038
# Epoch 17/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.1014 - categorical_accuracy: 0.6246 - val_loss: 0.9863 - val_categorical_accuracy: 0.6574
# Epoch 18/100
# 704/704 [==============================] - 18s 25ms/step - loss: 1.0872 - categorical_accuracy: 0.6272 - val_loss: 0.9020 - val_categorical_accuracy: 0.6884
# Epoch 19/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.0718 - categorical_accuracy: 0.6364 - val_loss: 0.7357 - val_categorical_accuracy: 0.7548
# Epoch 20/100
# 704/704 [==============================] - 19s 26ms/step - loss: 1.0465 - categorical_accuracy: 0.6437 - val_loss: 0.9036 - val_categorical_accuracy: 0.6994
# Epoch 21/100
# 704/704 [==============================] - 18s 26ms/step - loss: 1.0358 - categorical_accuracy: 0.6500 - val_loss: 0.7658 - val_categorical_accuracy: 0.7462
# Epoch 22/100
# 704/704 [==============================] - 17s 24ms/step - loss: 1.0122 - categorical_accuracy: 0.6577 - val_loss: 0.7525 - val_categorical_accuracy: 0.7436
# Epoch 23/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.9906 - categorical_accuracy: 0.6658 - val_loss: 0.7406 - val_categorical_accuracy: 0.7520
# Epoch 24/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.9823 - categorical_accuracy: 0.6707 - val_loss: 0.8087 - val_categorical_accuracy: 0.7356
# Epoch 25/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.9751 - categorical_accuracy: 0.6726 - val_loss: 0.7187 - val_categorical_accuracy: 0.7590
# Epoch 26/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.9621 - categorical_accuracy: 0.6771 - val_loss: 0.7716 - val_categorical_accuracy: 0.7544
# Epoch 27/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.9411 - categorical_accuracy: 0.6818 - val_loss: 0.7242 - val_categorical_accuracy: 0.7678
# Epoch 28/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.9414 - categorical_accuracy: 0.6866 - val_loss: 0.6119 - val_categorical_accuracy: 0.8004
# Epoch 29/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.9308 - categorical_accuracy: 0.6887 - val_loss: 0.6426 - val_categorical_accuracy: 0.7810
# Epoch 30/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.9178 - categorical_accuracy: 0.6919 - val_loss: 0.6864 - val_categorical_accuracy: 0.7742
# Epoch 31/100
# 704/704 [==============================] - 20s 28ms/step - loss: 0.9076 - categorical_accuracy: 0.6990 - val_loss: 0.6346 - val_categorical_accuracy: 0.7944
# Epoch 32/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8965 - categorical_accuracy: 0.7028 - val_loss: 0.6681 - val_categorical_accuracy: 0.7768
# Epoch 33/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.8962 - categorical_accuracy: 0.7027 - val_loss: 0.6085 - val_categorical_accuracy: 0.8010
# Epoch 34/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.8740 - categorical_accuracy: 0.7094 - val_loss: 0.7370 - val_categorical_accuracy: 0.7462
# Epoch 35/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8767 - categorical_accuracy: 0.7069 - val_loss: 0.6200 - val_categorical_accuracy: 0.7890
# Epoch 36/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8640 - categorical_accuracy: 0.7115 - val_loss: 0.5279 - val_categorical_accuracy: 0.8270
# Epoch 37/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8508 - categorical_accuracy: 0.7183 - val_loss: 0.6466 - val_categorical_accuracy: 0.7852
# Epoch 38/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.8412 - categorical_accuracy: 0.7174 - val_loss: 0.5654 - val_categorical_accuracy: 0.8108
# Epoch 39/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.8429 - categorical_accuracy: 0.7201 - val_loss: 0.5652 - val_categorical_accuracy: 0.8104
# Epoch 40/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8419 - categorical_accuracy: 0.7200 - val_loss: 0.6136 - val_categorical_accuracy: 0.7974
# Epoch 41/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.8322 - categorical_accuracy: 0.7243 - val_loss: 0.5846 - val_categorical_accuracy: 0.8066
# Epoch 42/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.8257 - categorical_accuracy: 0.7246 - val_loss: 0.5434 - val_categorical_accuracy: 0.8180
# Epoch 43/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.8109 - categorical_accuracy: 0.7318 - val_loss: 0.5644 - val_categorical_accuracy: 0.8128
# Epoch 44/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.8122 - categorical_accuracy: 0.7311 - val_loss: 0.5131 - val_categorical_accuracy: 0.8316
# Epoch 45/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.8077 - categorical_accuracy: 0.7305 - val_loss: 0.5122 - val_categorical_accuracy: 0.8334
# Epoch 46/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.8008 - categorical_accuracy: 0.7328 - val_loss: 0.6089 - val_categorical_accuracy: 0.7998
# Epoch 47/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.8030 - categorical_accuracy: 0.7354 - val_loss: 0.5035 - val_categorical_accuracy: 0.8278
# Epoch 48/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7900 - categorical_accuracy: 0.7397 - val_loss: 0.6408 - val_categorical_accuracy: 0.7792
# Epoch 49/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.7845 - categorical_accuracy: 0.7402 - val_loss: 0.5368 - val_categorical_accuracy: 0.8224
# Epoch 50/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7814 - categorical_accuracy: 0.7432 - val_loss: 0.8477 - val_categorical_accuracy: 0.7526
# Epoch 51/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7785 - categorical_accuracy: 0.7456 - val_loss: 0.5075 - val_categorical_accuracy: 0.8364
# Epoch 52/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7788 - categorical_accuracy: 0.7434 - val_loss: 0.5435 - val_categorical_accuracy: 0.8170
# Epoch 53/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7660 - categorical_accuracy: 0.7461 - val_loss: 0.5612 - val_categorical_accuracy: 0.8092
# Epoch 54/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.7634 - categorical_accuracy: 0.7504 - val_loss: 0.5239 - val_categorical_accuracy: 0.8270
# Epoch 55/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7646 - categorical_accuracy: 0.7496 - val_loss: 0.6785 - val_categorical_accuracy: 0.7800
# Epoch 56/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.7518 - categorical_accuracy: 0.7520 - val_loss: 0.5186 - val_categorical_accuracy: 0.8270
# Epoch 57/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.7509 - categorical_accuracy: 0.7506 - val_loss: 0.5200 - val_categorical_accuracy: 0.8330
# Epoch 58/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7442 - categorical_accuracy: 0.7542 - val_loss: 0.5037 - val_categorical_accuracy: 0.8320
# Epoch 59/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7407 - categorical_accuracy: 0.7535 - val_loss: 0.4966 - val_categorical_accuracy: 0.8370
# Epoch 60/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7371 - categorical_accuracy: 0.7583 - val_loss: 0.5381 - val_categorical_accuracy: 0.8296
# Epoch 61/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7367 - categorical_accuracy: 0.7535 - val_loss: 0.5562 - val_categorical_accuracy: 0.8258
# Epoch 62/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7284 - categorical_accuracy: 0.7610 - val_loss: 0.5633 - val_categorical_accuracy: 0.8150
# Epoch 63/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7358 - categorical_accuracy: 0.7563 - val_loss: 0.5091 - val_categorical_accuracy: 0.8412
# Epoch 64/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.7204 - categorical_accuracy: 0.7640 - val_loss: 0.5639 - val_categorical_accuracy: 0.8216
# Epoch 65/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7236 - categorical_accuracy: 0.7632 - val_loss: 0.4953 - val_categorical_accuracy: 0.8390
# Epoch 66/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7154 - categorical_accuracy: 0.7663 - val_loss: 0.7082 - val_categorical_accuracy: 0.7710
# Epoch 67/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7137 - categorical_accuracy: 0.7636 - val_loss: 0.5423 - val_categorical_accuracy: 0.8130
# Epoch 68/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.7189 - categorical_accuracy: 0.7628 - val_loss: 0.5922 - val_categorical_accuracy: 0.8120
# Epoch 69/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.7099 - categorical_accuracy: 0.7654 - val_loss: 0.6022 - val_categorical_accuracy: 0.8056
# Epoch 70/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7056 - categorical_accuracy: 0.7673 - val_loss: 0.4626 - val_categorical_accuracy: 0.8516
# Epoch 71/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.7031 - categorical_accuracy: 0.7712 - val_loss: 0.5618 - val_categorical_accuracy: 0.8236
# Epoch 72/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6929 - categorical_accuracy: 0.7688 - val_loss: 0.5973 - val_categorical_accuracy: 0.8158
# Epoch 73/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6872 - categorical_accuracy: 0.7727 - val_loss: 0.4818 - val_categorical_accuracy: 0.8408
# Epoch 74/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6960 - categorical_accuracy: 0.7710 - val_loss: 0.5383 - val_categorical_accuracy: 0.8246
# Epoch 75/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6911 - categorical_accuracy: 0.7734 - val_loss: 0.5188 - val_categorical_accuracy: 0.8322
# Epoch 76/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.6816 - categorical_accuracy: 0.7762 - val_loss: 0.5654 - val_categorical_accuracy: 0.8216
# Epoch 77/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6884 - categorical_accuracy: 0.7744 - val_loss: 0.4884 - val_categorical_accuracy: 0.8382
# Epoch 78/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6818 - categorical_accuracy: 0.7772 - val_loss: 0.4479 - val_categorical_accuracy: 0.8574
# Epoch 79/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6750 - categorical_accuracy: 0.7790 - val_loss: 0.5280 - val_categorical_accuracy: 0.8352
# Epoch 80/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6682 - categorical_accuracy: 0.7839 - val_loss: 0.4894 - val_categorical_accuracy: 0.8410
# Epoch 81/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6747 - categorical_accuracy: 0.7764 - val_loss: 0.5295 - val_categorical_accuracy: 0.8332
# Epoch 82/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6760 - categorical_accuracy: 0.7790 - val_loss: 0.4580 - val_categorical_accuracy: 0.8538
# Epoch 83/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6681 - categorical_accuracy: 0.7804 - val_loss: 0.5649 - val_categorical_accuracy: 0.8132
# Epoch 84/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6708 - categorical_accuracy: 0.7802 - val_loss: 0.4819 - val_categorical_accuracy: 0.8390
# Epoch 85/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.6620 - categorical_accuracy: 0.7817 - val_loss: 0.4839 - val_categorical_accuracy: 0.8462
# Epoch 86/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.6597 - categorical_accuracy: 0.7809 - val_loss: 0.4802 - val_categorical_accuracy: 0.8454
# Epoch 87/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6632 - categorical_accuracy: 0.7836 - val_loss: 0.7145 - val_categorical_accuracy: 0.7814
# Epoch 88/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6697 - categorical_accuracy: 0.7794 - val_loss: 0.5051 - val_categorical_accuracy: 0.8374
# Epoch 89/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6656 - categorical_accuracy: 0.7818 - val_loss: 0.4634 - val_categorical_accuracy: 0.8534
# Epoch 90/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6608 - categorical_accuracy: 0.7839 - val_loss: 0.4716 - val_categorical_accuracy: 0.8446
# Epoch 91/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.6539 - categorical_accuracy: 0.7878 - val_loss: 0.5252 - val_categorical_accuracy: 0.8308
# Epoch 92/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.6493 - categorical_accuracy: 0.7889 - val_loss: 0.4953 - val_categorical_accuracy: 0.8418
# Epoch 93/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6421 - categorical_accuracy: 0.7921 - val_loss: 0.4576 - val_categorical_accuracy: 0.8610
# Epoch 94/100
# 704/704 [==============================] - 17s 25ms/step - loss: 0.6553 - categorical_accuracy: 0.7870 - val_loss: 0.4716 - val_categorical_accuracy: 0.8484
# Epoch 95/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6520 - categorical_accuracy: 0.7867 - val_loss: 0.5368 - val_categorical_accuracy: 0.8360
# Epoch 96/100
# 704/704 [==============================] - 18s 25ms/step - loss: 0.6514 - categorical_accuracy: 0.7856 - val_loss: 0.4546 - val_categorical_accuracy: 0.8544
# Epoch 97/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.6500 - categorical_accuracy: 0.7865 - val_loss: 0.4578 - val_categorical_accuracy: 0.8564
# Epoch 98/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6407 - categorical_accuracy: 0.7886 - val_loss: 0.5303 - val_categorical_accuracy: 0.8290
# Epoch 99/100
# 704/704 [==============================] - 18s 26ms/step - loss: 0.6454 - categorical_accuracy: 0.7890 - val_loss: 0.5672 - val_categorical_accuracy: 0.8142
# Epoch 100/100
# 704/704 [==============================] - 19s 27ms/step - loss: 0.6410 - categorical_accuracy: 0.7896 - val_loss: 0.5317 - val_categorical_accuracy: 0.8364
